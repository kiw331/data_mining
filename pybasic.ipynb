# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/ch4_07.csv', encoding='utf-8', index_col=0)
df
# Out:
#   Unnamed: 0   1분기   2분기   3분기   4분기
# 0      2015년   500   450   520   610
# 1      2016년   690   700   820   900
# 2      2017년  1100  1030  1200  1380
# 3      2018년  1500  1650  1700  1850
# 4      2019년  1990  2020  2300  2420
# 5      2020년  1020  1600  2200  2550

# %%
years = df.index
years
# Out:
# Index(['2015년', '2016년', '2017년', '2018년', '2019년', '2020년'], dtype='object')

# %%
x = ['first', 'second', 'third', 'fourth']

for year in df.index:
    print(df.loc[year], type(df.loc[year]))
    plt.plot(x, df.loc[year])
    
plt.title('2015~2020 Quarterly sales')
plt.xlabel('Quarters')
plt.ylabel('sales')
plt.legend(['2015', '2016', '2017', '2018', '2019', '2020'])
# Out:
# 1분기    500
# 2분기    450
# 3분기    520
# 4분기    610
# Name: 2015년, dtype: int64 <class 'pandas.core.series.Series'>
# 1분기    690
# 2분기    700
# 3분기    820
# 4분기    900
# Name: 2016년, dtype: int64 <class 'pandas.core.series.Series'>
# 1분기    1100
# 2분기    1030
# 3분기    1200
# 4분기    1380
# Name: 2017년, dtype: int64 <class 'pandas.core.series.Series'>
# 1분기    1500
# 2분기    1650
# 3분기    1700
# 4분기    1850
# Name: 2018년, dtype: int64 <class 'pandas.core.series.Series'>
# 1분기    1990
# 2분기    2020
# 3분기    2300
# 4분기    2420
# Name: 2019년, dtype: int64 <class 'pandas.core.series.Series'>
# 1분기    1020
# 2분기    1600
# 3분기    2200
# 4분기    2550
# Name: 2020년, dtype: int64 <class 'pandas.core.series.Series'>

# %%
import matplotlib.font_manager as fm

font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')
print(font_list)
# Out:
# ['C:\\Windows\\Fonts\\consolai.ttf', 'C:\\Windows\\Fonts\\GILLUBCD.TTF', 'C:\\Windows\\Fonts\\H2SA1M.TTF', 'C:\\Windows\\Fonts\\NanumSquare_acL.ttf', 'C:\\Windows\\Fonts\\BOD_R.TTF', 'C:\\Windows\\Fonts\\seguisb.ttf', 'C:\\Windows\\Fonts\\HANDotumB.ttf', 'C:\\Windows\\Fonts\\GOTHIC.TTF', 'C:\\Windows\\Fonts\\H2GPRM.TTF', 'C:\\Windows\\Fonts\\calibrib.ttf', 'C:\\Windows\\Fonts\\corbelli.ttf', 'C:\\Windows\\Fonts\\ariblk.ttf', 'C:\\Windows\\Fonts\\framd.ttf', 'C:\\Windows\\Fonts\\consolab.ttf', 'C:\\Windows\\Fonts\\trebuc.ttf', 'C:\\Windows\\Fonts\\malgunbd.ttf', 'C:\\Windows\\Fonts\\himalaya.ttf', 'C:\\Windows\\Fonts\\LFAXDI.TTF', 'C:\\Windows\\Fonts\\NanumGothic.ttf', 'C:\\Windows\\Fonts\\COPRGTB.TTF', 'C:\\Windows\\Fonts\\SNAP____.TTF', 'C:\\Windows\\Fonts\\HANDotum.ttf', 'C:\\Windows\\Fonts\\gadugi.ttf', 'C:\\Windows\\Fonts\\BERNHC.TTF', 'C:\\Windows\\Fonts\\arialbd.ttf', 'C:\\Windows\\Fonts\\CALISTB.TTF', 'C:\\Windows\\Fonts\\CENTAUR.TTF', 'C:\\Windows\\Fonts\\AGENCYR.TTF', 'C:\\W
# ...

# %%
fontpath = r'C:\Windows\Fonts\malgunsl.ttf'
font_name = fm.FontProperties(fname=fontpath, size=50).get_name()
plt.rc('font', family=font_name)
print(plt.rcParams['font.family']) #적용됬는지 확인
# Out:
# ['Malgun Gothic']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터프레임 생성
data = [[490, 201, 0], [366, 197, 0], [863, 7993, 288]]
index = ['교수', '직원', '학생']
columns = ['찬성', '반대', '무효']

df = pd.DataFrame(data, index=index, columns=columns)

# 각 직책별 투표 결과 수평 막대 그래프
df.plot(kind='barh', stacked=True)
plt.title('직책별 투표 결과 (수평 막대 그래프)')
plt.xlabel('count')
plt.ylabel('position')
plt.legend(title='투표 옵션')
plt.show()

# %%
import matplotlib.pyplot as plt

x = [2016, 2017, 2018, 2019, 2020]
y = [350, 410, 520, 695, 543]

plt.plot(x, y)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/충북권 대학 등록금.csv', encoding='utf-8')
df
# Out:
#            학교명  구분      등록금
# 0      청주교육대학교  국립  3230000
# 1        충북대학교  국립  4272979
# 2      한국교원대학교  국립  3181645
# 3      한국교통대학교  국립  4106442
# 4   건국대학교(글로컬)  사립  7985995
# 5        극동대학교  사립  7467548
# 6    가톨릭꽃동네대학교  사립  7152463
# 7        서원대학교  사립  6912238
# 8        세명대학교  사립  6859293
# 9     순복음총회신학교  사립  5605779
# 10       우석대학교  사립  6920095
# 11       유원대학교  사립  7289106
# 12       중원대학교  사립  7400081
# 13       청주대학교  사립  7619982

# %%
import matplotlib.pyplot as plt
import numpy as np

# make data
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)

# plot:
fig, ax = plt.subplots()

ax.hist(x, bins=8, linewidth=0.5, edgecolor="white")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data:
np.random.seed(10)
D = np.random.normal((3, 5, 4), (1.25, 1.00, 1.25), (100, 3))

# plot
fig, ax = plt.subplots()
VP = ax.boxplot(D, positions=[2, 4, 6], widths=1.5, patch_artist=True,
                showmeans=False, showfliers=False,
                medianprops={"color": "white", "linewidth": 0.5},
                boxprops={"facecolor": "C0", "edgecolor": "white",
                          "linewidth": 0.5},
                whiskerprops={"color": "C0", "linewidth": 1.5},
                capprops={"color": "C0", "linewidth": 1.5})

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
data_his = df['등록금']


type(data_his)
# Out:
# pandas.core.series.Series
