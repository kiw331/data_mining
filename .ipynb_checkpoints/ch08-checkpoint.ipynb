# %%
# %pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.2-cp39-cp39-win_amd64.whl (153 kB)
#      ---------------------------------------- 0.0/153.3 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/153.3 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/153.3 kB ? eta -:--:--
#      -------------- ---------------------- 61.4/153.3 kB 409.6 kB/s eta 0:00:01
#      ---------------------------- ------- 122.9/153.3 kB 654.9 kB/s eta 0:00:01
#      ------------------------------------ 153.3/153.3 kB 704.7 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6.1 in c:\users\kiw\anaconda3\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\kiw\anaconda3\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: pillow in c:\users\kiw\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\kiw\anaconda3\lib\site-packages (from matplotlib->wordcloud) (5.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kiw\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kiw\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kiw\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kiw\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\kiw\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kiw\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kiw\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\kiw\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\kiw\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import glob
import re
from functools import reduce
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS, WordCloud

# %%
# %pwd
# Out:
# 'c:\\Users\\kiw\\github_15zd\\data_mining'

# %%
all_files = glob.glob('data/myCabinetExcelData*.xls')
all_files #출력하여 내용 확인
# Out:
# ['data\\myCabinetExcelData (1).xls',
#  'data\\myCabinetExcelData (2).xls',
#  'data\\myCabinetExcelData (3).xls',
#  'data\\myCabinetExcelData (4).xls',
#  'data\\myCabinetExcelData (5).xls',
#  'data\\myCabinetExcelData (6).xls',
#  'data\\myCabinetExcelData (7).xls',
#  'data\\myCabinetExcelData (8).xls',
#  'data\\myCabinetExcelData (9).xls',
#  'data\\myCabinetExcelData.xls']

# %%
# %pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#      -------------------------------------- - 92.2/96.5 kB 5.1 MB/s eta 0:00:01
#      ---------------------------------------- 96.5/96.5 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
all_files_data = [] #저장할 리스트
for file in all_files: 
    data_frame = pd.read_excel(file) 
    all_files_data.append(data_frame) 
all_files_data[0] #작업 내용 확인
# Out:
#     Unnamed: 0   번호                                                 제목  \
# 0          NaN    1  Call for Special Issue Papers: Cloud Computing...
# 1          NaN    2  SOOM: Sort-Based Optimizer for Big Data Multi-...
# 2          NaN    3  The U.S. Army Person-Event Data Environment: A...
# 3          NaN    4  Call for Special Issue Papers: Big Scientific ...
# 4          NaN    5               Correction to: Big Data 2016;4:60–66
# ..         ...  ...                                                ...
# 95         NaN   96  HDM: A Composable Framework for Big Data Proce...
# 96         NaN   97  Distributed Feature Selection for Efficient Ec...
# 97         NaN   98  A concentric framework for leveraging big data...
# 98         NaN   99  Structural Balance Theory-Based E-Commerce Rec...
# 99         NaN  100  Perceptions of independent financial advisors ...
#
#                                                    저자               출판사   출판일
# 0    Verdu, Elena; Nieto, Yuri Vanessa; Saleem, Nasir  Mary Ann Leibert  2021
# 1   Sahal, Radhya; Khafagy, Mohammed H.; Omara, Fa...  Mary Ann Leibert  2020
# 2                                             unknown  Mary Ann Leibert  2015
# 3   Anaraki, Farhad Pourkamali; Hariri-Ardebili, M...  Mary Ann Leibert  2021
# 4                                             unknown  Mary Ann Leibert  2016
# ..                                                ...               ...   ...
# 95                  Wu, D.; Zhu, L.; Lu, Q.; Sakr, S.           unknown  2018
# 96     Zhao, L.; Chen, Z.; Hu, Y.; Min, G.; Jiang, Z.           unknown  2018
# 97   Chuang, Ta-Tao; Nakatani, Kazuo; Patil, Vivek H.      Inderscience  2020
# 98  Qi, L.; Xu, X.; Zhang, X.; Dou, W.; Hu, C.; Zh...           unknown  2018
# 99            Grishikashvili, Ketty; Bechter, Clemens      Inderscience  2019
#
# [100 rows x 6 columns]

# %%
#데이터 병합
all_files_data_concat = pd.concat(all_files_data, axis = 0, ignore_index = True) 
all_files_data_concat #출력하여 내용 확인
# Out:
#      Unnamed: 0   번호                                                 제목  \
# 0           NaN    1  Call for Special Issue Papers: Cloud Computing...
# 1           NaN    2  SOOM: Sort-Based Optimizer for Big Data Multi-...
# 2           NaN    3  The U.S. Army Person-Event Data Environment: A...
# 3           NaN    4  Call for Special Issue Papers: Big Scientific ...
# 4           NaN    5               Correction to: Big Data 2016;4:60–66
# ..          ...  ...                                                ...
# 995         NaN   96  Call for Special Issue Papers: Big Data Analyt...
# 996         NaN   97                         Big Data Literature Search
# 997         NaN   98  Agricultural Disaster Risk Management and Capa...
# 998         NaN   99  A Survey of Biological Data in a Big Data Pers...
# 999         NaN  100  Exploiting Reused-Based Sharing Work Opportuni...
#
#                                                     저자               출판사   출판일
# 0     Verdu, Elena; Nieto, Yuri Vanessa; Saleem, Nasir  Mary Ann Leibert  2021
# 1    Sahal, Radhya; Khafagy, Mohammed H.; Omara, Fa...  Mary Ann Leibert  2020
# 2                                              unknown  Mary Ann Leibert  2015
# 3    Anaraki, Farhad Pourkamali; Hariri-Ardebili, M...  Mary Ann Leibert  2021
# 4                                              unknown  Mary Ann Leibert  2016
# ..                                                 ...               ...   ...
# 995  Balamurugan, S.; Muthu, Bala Anand; Peng, Shen...  Mary Ann Leibert  2020
# 996                                            unknown  Mary Ann Leibert  2014
# 997  Wang, Caili; Gao, Yuwen; Aziz, Asad; Ogunmola,...  Mary Ann Leibert  2022
# 998  Dall'Alba, Gabriel; Casa, Pedro Lenz; Abreu, F...  Mary Ann Leibert  2022
# 999  Sahal, Radhya; Khafagy, Mohammed H.; Omara, Fa...  Mary Ann Leibert  2021
#
# [1000 rows x 6 columns]

# %%
all_files_data_concat.to_csv('data/riss_bigdata.csv', encoding = 'utf-8', index = False)

# %%
# 수집한 데이터에서 제목을 추출하여 전처리를 수행
all_title = all_files_data_concat['제목'] 
all_title #출력하여 내용 확인
# Out:
# 0      Call for Special Issue Papers: Cloud Computing...
# 1      SOOM: Sort-Based Optimizer for Big Data Multi-...
# 2      The U.S. Army Person-Event Data Environment: A...
# 3      Call for Special Issue Papers: Big Scientific ...
# 4                   Correction to: Big Data 2016;4:60–66
#                              ...
# 995    Call for Special Issue Papers: Big Data Analyt...
# 996                           Big Data Literature Search
# 997    Agricultural Disaster Risk Management and Capa...
# 998    A Survey of Biological Data in a Big Data Pers...
# 999    Exploiting Reused-Based Sharing Work Opportuni...
# Name: 제목, Length: 1000, dtype: object

# %%
# 패키지 다운로드
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kiw\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kiw\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kiw\AppData\Roaming\nltk_data...
# True

# %%
# 전처리 작업을 위해 nltk.corpus에서 제공하는 영어 불용어stopwords.words("english")를 불러와서 저장
stopWords = set(stopwords.words("english"))

# 그 후, 표제어 추출 작업을 제공하는 WordNetLemmatizer 객체를 생성
lemma = WordNetLemmatizer()

# %%
# 오류 방지
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\kiw\AppData\Roaming\nltk_data...
# True

# %%
words = [] 

for title in all_title: 
    EnWords = re.sub(r"[^a-zA-Z]+", " ", str(title)) #대문자 소문자로 (정규화)
    EnWordsToken = word_tokenize(EnWords.lower()) 
    EnWordsTokenStop = [w for w in EnWordsToken if w not in stopWords] #리스트 표현식: w에 대해서 stopWords에 포함 안되는지 체크
    EnWordsTokenStopLemma = [lemma.lemmatize(w) for w in EnWordsTokenStop] 
    words.append(EnWordsTokenStopLemma)
    
print(words) #출력하여 내용 확인
# Out:
# [['call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot'], ['soom', 'sort', 'based', 'optimizer', 'big', 'data', 'multi', 'query'], ['u', 'army', 'person', 'event', 'data', 'environment', 'military', 'civilian', 'big', 'data', 'enterprise'], ['call', 'special', 'issue', 'paper', 'big', 'scientific', 'data', 'machine', 'learning', 'science', 'engineering'], ['correction', 'big', 'data'], ['ensemble', 'based', 'scalable', 'approach', 'intrusion', 'detection', 'using', 'big', 'data', 'framework'], ['big', 'uncertain', 'data', 'multiple', 'sensor', 'efficient', 'processing', 'high', 'order', 'multi', 'hypothesis', 'evidence', 'theoretic', 'approach'], ['deep', 'learning', 'big', 'sparse', 'behavioral', 'data'], ['internet', 'thing', 'based', 'optimized', 'routing', 'big', 'data', 'gathering', 'system', 'landslide', 'detection'], ['big', 'data', 'application', 'guangzhou', 'restaurant', 'analysis'], ['labor', 'economist', 'get', 'microscope', 'big', 'data', 'labor', 'market', 'analysis'], ['big', 'data', 'support', 'sustainable', 'development', 'goal', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goal', 'cbas'], ['new', 'discrimination', 'diagram', 'basalt', 'based', 'big', 'data', 'research'], ['optimal', 'feature', 'selection', 'big', 'data', 'classification', 'firefly', 'lion', 'assisted', 'model'], ['toward', 'general', 'framework', 'multimodal', 'big', 'data', 'analysis'], ['unsupervised', 'tensor', 'mining', 'big', 'data', 'practitioner'], ['using', 'big', 'data', 'understand', 'human', 'condition', 'kavli', 'human', 'project'], ['big', 'data', 'analytics', 'data', 'management', 'perspective', 'public', 'administration'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'intelligent', 'system', 'cybersecurity'], ['online', 'analytical', 'processing', 'business', 'intelligence', 'big', 'data'], ['national', 'survey', 'population', 'health', 'big', 'data', 'analytics', 'mobile', 'health', 'monitor'], ['call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education'], ['call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education'], ['recent', 'advance', 'earth', 'observation', 'big', 'data', 'hydrology'], ['challenge', 'big', 'data', 'earth'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'internet', 'thing', 'complex', 'information', 'system', 'selection', 'iotbds', 'complexis'], ['big', 'data', 'healthcare', 'opportunity', 'challenge'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'intelligent', 'system', 'cybersecurity'], ['big', 'multimodal', 'data', 'analysis', 'model', 'performance', 'analysis'], ['big', 'data', 'predictive', 'analytics', 'health', 'care'], ['earth', 'observation', 'geospatial', 'big', 'data', 'management', 'engagement', 'stakeholder', 'hungary', 'support', 'sdgs'], ['call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot'], ['atmospheric', 'ecosystem', 'big', 'data', 'providing', 'key', 'contribution', 'reaching', 'united', 'nation', 'sustainable', 'development', 'goal'], ['spatial', 'pattern', 'urban', 'green', 'space', 'actual', 'utilization', 'status', 'china', 'based', 'big', 'data', 'analysis'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'business'], ['call', 'paper', 'special', 'issue', 'computational', 'propaganda', 'political', 'big', 'data'], ['new', 'big', 'data', 'approach', 'based', 'geoecological', 'information', 'modeling', 'system'], ['moth', 'flame', 'optimization', 'bat', 'optimization', 'map', 'reduce', 'framework', 'big', 'data', 'clustering', 'using', 'moth', 'flame', 'bat', 'optimization', 'sparse', 'fuzzy', 'c', 'mean'], ['big', 'data', 'robotics'], ['overcoming', 'resistance', 'big', 'data', 'operational', 'change', 'interactive', 'data', 'visualization'], ['big', 'data', 'little', 'data', 'care', 'coo ...

# %%
#람다식: x,y가 주어졌을 때 리터값이 x+y
words2 = list(reduce(lambda x, y: x+y, words))
print(words2) #출력하여 내용 확인
# Out:
# ['call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot', 'soom', 'sort', 'based', 'optimizer', 'big', 'data', 'multi', 'query', 'u', 'army', 'person', 'event', 'data', 'environment', 'military', 'civilian', 'big', 'data', 'enterprise', 'call', 'special', 'issue', 'paper', 'big', 'scientific', 'data', 'machine', 'learning', 'science', 'engineering', 'correction', 'big', 'data', 'ensemble', 'based', 'scalable', 'approach', 'intrusion', 'detection', 'using', 'big', 'data', 'framework', 'big', 'uncertain', 'data', 'multiple', 'sensor', 'efficient', 'processing', 'high', 'order', 'multi', 'hypothesis', 'evidence', 'theoretic', 'approach', 'deep', 'learning', 'big', 'sparse', 'behavioral', 'data', 'internet', 'thing', 'based', 'optimized', 'routing', 'big', 'data', 'gathering', 'system', 'landslide', 'detection', 'big', 'data', 'application', 'guangzhou', 'restaurant', 'analysis', 'labor', 'economist', 'get', 'microscope', 'big', 'data', 'labor', 'market', 'analysis', 'big', 'data', 'support', 'sustainable', 'development', 'goal', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goal', 'cbas', 'new', 'discrimination', 'diagram', 'basalt', 'based', 'big', 'data', 'research', 'optimal', 'feature', 'selection', 'big', 'data', 'classification', 'firefly', 'lion', 'assisted', 'model', 'toward', 'general', 'framework', 'multimodal', 'big', 'data', 'analysis', 'unsupervised', 'tensor', 'mining', 'big', 'data', 'practitioner', 'using', 'big', 'data', 'understand', 'human', 'condition', 'kavli', 'human', 'project', 'big', 'data', 'analytics', 'data', 'management', 'perspective', 'public', 'administration', 'call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'intelligent', 'system', 'cybersecurity', 'online', 'analytical', 'processing', 'business', 'intelligence', 'big', 'data', 'national', 'survey', 'population', 'health', 'big', 'data', 'analytics', 'mobile', 'health', 'monitor', 'call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education', 'call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education', 'recent', 'advance', 'earth', 'observation', 'big', 'data', 'hydrology', 'challenge', 'big', 'data', 'earth', 'call', 'special', 'issue', 'paper', 'big', 'data', 'internet', 'thing', 'complex', 'information', 'system', 'selection', 'iotbds', 'complexis', 'big', 'data', 'healthcare', 'opportunity', 'challenge', 'call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'intelligent', 'system', 'cybersecurity', 'big', 'multimodal', 'data', 'analysis', 'model', 'performance', 'analysis', 'big', 'data', 'predictive', 'analytics', 'health', 'care', 'earth', 'observation', 'geospatial', 'big', 'data', 'management', 'engagement', 'stakeholder', 'hungary', 'support', 'sdgs', 'call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot', 'atmospheric', 'ecosystem', 'big', 'data', 'providing', 'key', 'contribution', 'reaching', 'united', 'nation', 'sustainable', 'development', 'goal', 'spatial', 'pattern', 'urban', 'green', 'space', 'actual', 'utilization', 'status', 'china', 'based', 'big', 'data', 'analysis', 'call', 'special', 'issue', 'paper', 'big', 'data', 'business', 'call', 'paper', 'special', 'issue', 'computational', 'propaganda', 'political', 'big', 'data', 'new', 'big', 'data', 'approach', 'based', 'geoecological', 'information', 'modeling', 'system', 'moth', 'flame', 'optimization', 'bat', 'optimization', 'map', 'reduce', 'framework', 'big', 'data', 'clustering', 'using', 'moth', 'flame', 'bat', 'optimization', 'sparse', 'fuzzy', 'c', 'mean', 'big', 'data', 'robotics', 'overcoming', 'resistance', 'big', 'data', 'operational', 'change', 'interactive', 'data', 'visualization', 'big', 'data', 'little', 'data', 'care', 'coordination', 'medicare', 'beneficiary', 'medigap', 'coverage', 'big', 'data', 'dri ...

# %%
#단어 빈도 카운트
count = Counter(words2) #함수 안쓰고 딕셔너리 노가다 할 수도 있다.
count
# Out:
# Counter({'call': 35,
#          'special': 38,
#          'issue': 48,
#          'paper': 32,
#          'cloud': 30,
#          'computing': 25,
#          'big': 1111,
#          'data': 1238,
#          'cognitive': 4,
#          'iot': 9,
#          'soom': 1,
#          'sort': 1,
#          'based': 103,
#          'optimizer': 1,
#          'multi': 12,
#          'query': 4,
#          'u': 8,
#          'army': 2,
#          'person': 1,
#          'event': 1,
#          'environment': 12,
#          'military': 1,
#          'civilian': 1,
#          'enterprise': 8,
#          'scientific': 10,
#          'machine': 26,
#          'learning': 48,
#          'science': 35,
#          'engineering': 12,
#          'correction': 4,
#          'ensemble': 4,
#          'scalable': 14,
#          'approach': 59,
#          'intrusion': 1,
#          'detection': 12,
#          'using': 56,
#          'framework': 35,
#          'uncertain': 1,
#          'multiple': 4,
#          'sensor': 7,
#          'efficient': 18,
#          'processing': 26,
#          'high': 13,
#          'order': 3,
#          'hypothesis': 1,
#          'evidence': 10,
#          'theoretic': 2,
#          'deep': 13,
#          'sparse': 4,
#          'behavioral': 3,
#          'internet': 18,
#          'thing': 15,
#          'optimized': 2,
#          'routing': 2,
#          'gathering': 4,
#          'system': 62,
#          'landslide': 1,
#          'application': 41,
#          'guangzhou': 1,
#          'restaurant': 1,
#          'analysis': 92,
#          'labor': 2,
#          'economist': 1,
#          'get': 2,
#          'microscope': 1,
#          'market': 10,
#          'support': 11,
#          'sustainable': 18,
#          'development': 20,
#          'goal': 12,
#          'celebration': 2,
#          'establishment': 3,
#          'international': 6,
#          'research': 32,
#          'center': 7,
#          'cbas': 2,
#          'new': 41,
#          'discrimination': 2,
#          'diagram': 1,
#          'basalt': 1,
#          'optimal': 2,
#          'feature': 7,
#          'selection': 9,
#          'classification': 10,
#          'firefly': 1,
#          'lion': 1,
#          'assisted': 5,
#          'model': 45,
#          'toward': 8,
#          'general': 3,
#          'multimodal': 2,
#          'unsupervised': 1,
#          'tensor': 4,
#          'mining': 26,
#          'practitioner': 2,
#          'understand': 1,
#          'human': 11,
#          'condition': 2,
#          'kavli': 1,
#          'project': 5,
#          'analytics': 110,
#          'management': 33,
#          'perspective': 24,
#          'public': 10,
#          'administration': 2,
#          'intelligent': 15,
#          'cybersecurity': 4,
#          'online': 13,
#          'analytical': 2,
#          'business': 23,
#          'intelligence': 21,
#          'national': 5,
#          'survey': 18,
#          'population': 5,
#          'health': 33,
#          'mobile': 6,
#          'monitor': 1,
#          'multimedia': 5,
#          'education': 9,
#          'recent': 6,
#          'advance': 5,
#          'earth': 25,
#          'observation': 5,
#          'hydrology': 1,
#          'challenge': 44,
#          'complex': 4,
#          'information': 22,
#          'iotbds': 1,
#          'complexis': 1,
#          'healthcare': 17,
#          'opportunity': 27,
#          'performance': 25,
#          'predictive': 7,
#          'care': 11,
#          'geospatial': 4,
#          'engagement': 1,
#          'stakeholder': 3,
#          'hungary': 1,
#          'sdgs': 1,
#          'atmospheric': 1,
#          'ecosystem': 2,
#          'providing': 2,
#          'key': 6,
#          'contribution': 1,
#          'reaching': 1,
#          'united': 5,
#          'nation': 1,
#          'spatial': 7,
#          'pattern': 11,
#          'urban': 6,
#          'green': 7,
#          'space': 5,
#          'actual': 1,
#          'utilization': 4,
#          'status': 6,
#          'china': 18,
#          'computational': 9,
#          'propaganda': 3,
#          'political': 7,
#          'geoecological': 1,
#          'modeling': 13,
#          'moth': 2,
#          'flame': 2,
#          'optimization': 24,
#          'bat': 2,
#          'map': 4,
#          'reduce': 2,
#          'clustering': 12,
#          'fuzzy': 7,
#          'c': 3,
#          'mean': 9,
#          'robotics': 3,
#          'overcoming': 1,
#          'resistance': 3,
#          'operational': 3,
#          'change': 4,
#          'interactive': 2,
#          'visualization': 7,
#          'little': 10,
#          'coordination': 1,
#          'medicare': 1,
#          'beneficiary': 1,
#          'medigap': 1,
#          'coverage': 2,
#          'drive': 2,
#          'enabler': 1,
#          'primary': 2,
#          'industrial': 8,
#          'spatiotemporal': 2,
#          'interval': 3,
#          'leveraging': 8,
#          'case': 14,
#          'kenyan': 1,
#          'telecom': 2,
#          'agile': 1,
#          'web': 8,
#          'architecture': 12,
#          'centric': 1,
#          'improved': 5,
#          'stock': 4,
#          'index': 6,
#          'prediction': 15,
#          'cnn': 1,
#          'gru': 1,
#          'current': 9,
#          'potential': 8,
#          'solution': 12,
#          'review': 21,
#          'border': 1,
#          'crossing': 1,
#          'transportation': 7,
#          'modelling': 3,
#          'analyzing': 6,
#          'smart': 23,
#          'metering': 2,
#          'towards': 12,
#          'differentiated': 1,
#          'user': 4,
#          'service': 21,
#          'sublinear': 1,
#          'guest': 13,
#          'editorial': 16,
#          'infrastructure': 12,
#          'investigating': 1,
#          'class': 1,
#          'rarity': 1,
#          'landscape': 3,
#          'influence': 1,
#          'finance': 2,
#          'scholar': 3,
#          'discovery': 13,
#          'collaboration': 6,
#          'overview': 4,
#          'distributed': 23,
#          'algorithm': 36,
#          'understanding': 13,
#          'trend': 10,
#          'technology': 27,
#          'patent': 2,
#          'cited': 1,
#          'scholarly': 5,
#          'work': 10,
#          'speed': 1,
#          'unveiling': 1,
#          'storage': 9,
#          'distribution': 10,
#          'sub': 1,
#          'datasets': 2,
#          'petuum': 1,
#          'platform': 34,
#          'large': 12,
#          'scale': 12,
#          'spectral': 1,
#          'managing': 5,
#          'operation': 5,
#          'eeg': 1,
#          'seizure': 1,
#          'bci': 1,
#          'via': 9,
#          'ethical': 2,
#          'concern': 3,
#          'memory': 7,
#          'scaling': 2,
#          'hybrid': 4,
#          'parallel': 7,
#          'preserving': 3,
#          'privacy': 11,
#          'k': 9,
#          'anonymisation': 1,
#          'palopro': 1,
#          'knowledge': 10,
#          'extraction': 3,
#          'social': 19,
#          'news': 4,
#          'algorithmseer': 1,
#          'extracting': 2,
#          'searching': 1,
#          'evolving': 2,
#          'role': 13,
#          'fpga': 1,
#          'branch': 1,
#          'decoder': 1,
#          'network': 26,
#          'adaptive': 7,
#          'temporal': 5,
#          'reconstruction': 2,
#          'simulation': 3,
#          'secure': 3,
#          'owner': 1,
#          'scheme': 6,
#          'fast': 3,
#          'semantic': 7,
#          'composition': 2,
#          'deduplication': 3,
#          'encrypted': 1,
#          'continued': 3,
#          'five': 3,
#          'layer': 2,
#          'monitoring': 12,
#          'camera': 1,
#          'driven': 71,
#          'surveillance': 1,
#          'video': 1,
#          'thermal': 2,
#          'aware': 7,
#          'dvfs': 1,
#          'enabled': 9,
#          'task': 2,
#          'scheduling': 10,
#          'flexible': 3,
#          'metadata': 2,
#          'indexing': 1,
#          'real': 18,
#          'time': 18,
#          'comparison': 2,
#          'nosql': 4,
#          'reference': 4,
#          'introducing': 1,
#          'perform': 1,
#          'max': 1,
#          'min': 1,
#          'fair': 1,
#          'resource': 6,
#          'allocation': 5,
#          'stream': 4,
#          'shared': 2,
#          'ieee': 2,
#          'transaction': 2,
#          'vol': 2,
#          'resting': 1,
#          'state': 12,
#          'fmri': 2,
#          'functional': 1,
#          'connectivity': 1,
#          'preprocessing': 1,
#          'pipeline': 3,
#          'topological': 1,
#          'availability': 1,
#          'assurance': 1,
#          'extended': 3,
#          'spatio': 3,
#          'granger': 1,
#          'causality': 1,
#          'air': 4,
#          'quality': 7,
#          'estimation': 6,
#          'heterogeneous': 5,
#          'taxi': 2,
#          'passenger': 1,
#          'demand': 3,
#          'roving': 1,
#          'similarity': 2,
#          'overfitting': 1,
#          'hdm': 1,
#          'composable': 1,
#          'economic': 1,
#          'concentric': 1,
#          'value': 10,
#          'structural': 3,
#          'balance': 2,
#          'theory': 5,
#          'e': 7,
#          'commerce': 3,
#          'recommendation': 7,
#          'rating': 3,
#          'perception': 4,
#          'independent': 3,
#          'financial': 10,
#          'advisor': 1,
#          'usefulness': 1,
#          'context': 8,
#          'decision': 15,
#          'making': 16,
#          'uk': 1,
#          'consistency': 2,
#          'database': 10,
#          'corporate': 3,
#          'governance': 5,
#          'fraud': 2,
#          'annual': 1,
#          'report': 3,
#          'kvasir': 1,
#          'provision': 2,
#          'semantically': 2,
#          'relevant': 2,
#          'content': 4,
#          'enhanced': 4,
#          'method': 25,
#          'aid': 1,
#          'trajectory': 2,
#          'recognition': 1,
#          'longitudinal': 1,
#          'dip': 1,
#          'svm': 2,
#          'kernel': 5,
#          'vector': 3,
#          'handling': 4,
#          'apache': 4,
#          'spark': 5,
#          'hierarchical': 1,
#          'image': 5,
#          'hybridisation': 1,
#          'classifier': 3,
#          'anomaly': 3,
#          'frontier': 4,
#          'comprehensive': 3,
#          'view': 4,
#          'cube': 1,
#          'interoperability': 2,
#          'gsio': 1,
#          'programmatic': 1,
#          'interface': 1,
#          'delivering': 1,
#          'achieving': 1,
#          'belt': 2,
#          'road': 1,
#          'region': 3,
#          'facilitates': 1,
#          'semantics': 4,
#          'way': 6,
#          'open': 5,
#          'geosocial': 1,
#          'medium': 14,
#          'crowdsourced': 1,
#          'evaluating': 4,
#          'partnership': 1,
#          'increasing': 1,
#          'use': 22,
#          'australian': 1,
#          'climate': 2,
#          'ceph': 1,
#          'strategy': 9,
#          'gridded': 1,
#          'remote': 5,
#          'sensing': 8,
#          'core': 3,
#          'processor': 4,
#          'many': 1,
#          'co': 2,
#          'supercomputer': 1,
#          'beacon': 1,
#          'geocomputation': 1,
#          'geo': 2,
#          'visual': 3,
#          'transport': 2,
#          'greater': 1,
#          'sydney': 1,
#          'generalized': 3,
#          'supervised': 2,
#          'produce': 1,
#          'provincial': 1,
#          'wetland': 1,
#          'inventory': 1,
#          'google': 3,
#          'engine': 3,
#          'ontology': 3,
#          'graph': 5,
#          'stewardship': 1,
#          'innovative': 1,
#          'sentinel': 2,
#          'landsat': 2,
#          'imagery': 1,
#          'global': 11,
#          'settlement': 1,
#          'mapping': 7,
#          'exploiting': 3,
#          'first': 3,
#          'experience': 3,
#          'timescan': 1,
#          'chain': 7,
#          'grid': 7,
#          'impact': 14,
#          'wechat': 1,
#          'blood': 2,
#          'donation': 2,
#          'behavior': 8,
#          'study': 19,
#          'sentiment': 5,
#          'educational': 2,
#          'simd': 1,
#          'mcmc': 1,
#          'sampling': 4,
#          'bayesian': 4,
#          'small': 18,
#          'sector': 7,
#          'improving': 3,
#          'shuffle': 1,
#          'phase': 4,
#          'hadoop': 4,
#          'bigger': 3,
#          'biggest': 3,
#          'repository': 2,
#          'balloon': 1,
#          'unprecedented': 1,
#          'level': 2,
#          'coping': 2,
#          'transforming': 5,
#          'insight': 10,
#          'nearest': 4,
#          'neighbor': 3,
#          'obtain': 1,
#          'bolstering': 1,
#          'supply': 6,
#          'integration': 5,
#          'capability': 9,
#          'moderating': 2,
#          'culture': 2,
#          'city': 8,
#          'meet': 7,
#          'formal': 1,
#          'practical': 4,
#          'novel': 7,
#          'paradigm': 4,
#          'forecasting': 5,
#          'organisation': 2,
#          'leverage': 3,
#          'maturity': 1,
#          'quantile': 1,
#          'regression': 2,
#          'divide': 2,
#          'conquer': 1,
#          'statistical': 9,
#          'double': 1,
#          'log': 1,
#          'skew': 1,
#          'symmetric': 1,
#          'error': 6,
#          'result': 1,
#          'output': 1,
#          'process': 23,
#          'attribute': 1,
#          'designing': 2,
#          'operating': 1,
#          'mine': 3,
#          'initiative': 3,
#          'sharing': 10,
#          'thanados': 1,
#          'isoarch': 1,
#          'early': 2,
#          'medieval': 1,
#          'cemetery': 1,
#          'austria': 1,
#          'discretization': 1,
#          'taxonomy': 1,
#          'always': 1,
#          'yield': 2,
#          'benefit': 7,
#          'geographical': 1,
#          'automated': 1,
#          'slicing': 1,
#          'validation': 1,
#          'ai': 4,
#          'build': 2,
#          'better': 3,
#          'em': 2,
#          'detailed': 1,
#          'prominent': 1,
#          'compression': 5,
#          'used': 5,
#          'reducing': 2,
#          'volume': 2,
#          'theme': 1,
#          'crime': 1,
#          'electrophysiology': 2,
#          'collection': 2,
#          'recombine': 1,
#          'r': 9,
#          'complexity': 1,
#          'haery': 1,
#          'accumulative': 1,
#          'dimensional': 3,
#          'gamma': 1,
#          'matrix': 3,
#          'summarize': 1,
#          'dense': 1,
#          'set': 5,
#          'security': 15,
#          'applying': 5,
#          'kansei': 1,
#          'hotel': 1,
#          'portfolio': 2,
#          'successful': 1,
#          'improves': 1,
#          'fusion': 5,
#          'mapreduce': 8,
#          'programming': 3,
#          'cyber': 2,
#          'physical': 4,
#          'criminal': 2,
#          'investigation': 3,
#          'dynamic': 8,
#          'swarm': 3,
#          'entity': 1,
#          'communication': 6,
#          'assessment': 9,
#          'peer': 2,
#          'produced': 1,
#          'implicit': 2,
#          'wikipedia': 1,
#          'single': 1,
#          'cell': 4,
#          'transcriptomics': 1,
#          'grand': 2,
#          'done': 1,
#          'conference': 2,
#          'bigcomp': 1,
#          'academic': 2,
#          'librarian': 4,
#          'competency': 2,
#          'skill': 2,
#          'implementation': 5,
#          'library': 1,
#          'chicken': 1,
#          'foraging': 1,
#          'belief': 2,
#          'revised': 1,
#          'pyramid': 1,
#          'acquired': 1,
#          'multichannel': 1,
#          'wireless': 5,
#          'active': 1,
#          'control': 12,
#          'industry': 16,
#          'tool': 4,
#          'experimental': 3,
#          'evaluation': 5,
#          'partner': 1,
#          'allina': 1,
#          'team': 5,
#          'catalyst': 2,
#          'garner': 1,
#          'michael': 2,
#          'buck': 2,
#          'talk': 1,
#          'living': 1,
#          'dream': 3,
#          'bioinformaticist': 1,
#          'emerging': 3,
#          'alternative': 1,
#          'warehouse': 5,
#          'coal': 1,
#          'fired': 1,
#          'power': 8,
#          'plant': 1,
#          'exploring': 7,
#          'fundamental': 1,
#          'problem': 11,
#          'dimensionality': 1,
#          'reduction': 3,
#          'sdn': 1,
#          'advanced': 7,
#          'phone': 1,
#          'compute': 2,
#          'mobility': 6,
#          'scenario': 3,
#          'future': 17,
#          'mongodb': 1,
#          'modular': 1,
#          'building': 8,
#          'rule': 4,
#          'granularity': 1,
#          'deal': 5,
#          'heavy': 1,
#          'tailed': 1,
#          'analysing': 3,
#          'repeat': 1,
#          'comparing': 2,
#          'world': 20,
#          'regional': 3,
#          'bibliometric': 4,
#          'holistic': 2,
#          'watchdog': 1,
#          'name': 1,
#          'matching': 1,
#          'risk': 13,
#          'decisional': 1,
#          'word': 1,
#          'mouth': 1,
#          'csr': 1,
#          'twitter': 3,
#          'incremental': 4,
#          'mr': 2,
#          'plot': 1,
#          'distinguishing': 1,
#          'barrier': 2,
#          'embedding': 1,
#          'factory': 2,
#          'sap': 1,
#          'consultant': 1,
#          'retail': 1,
#          'apriori': 1,
#          'subdata': 1,
#          'medical': 15,
#          'device': 8,
#          'straggler': 1,
#          'rescheduling': 1,
#          'slow': 1,
#          'running': 1,
#          'lfcso': 1,
#          'lvq': 1,
#          'pso': 1,
#          'effect': 2,
#          'design': 11,
#          'methodology': 4,
#          'measurement': 7,
#          'skyline': 1,
#          'computation': 2,
#          'hyper': 1,
#          'convergent': 2,
#          'innovation': 9,
#          'unlocking': 1,
#          'causal': 1,
#          'relation': 2,
#          'manufacturing': 8,
#          'firm': 6,
#          'consensus': 1,
#          'lime': 1,
#          'predicting': 6,
#          'amazon': 1,
#          'product': 6,
#          'responding': 1,
#          'turbulence': 1,
#          'mass': 1,
#          'customization': 1,
#          'path': 1,
#          'success': 2,
#          'banking': 1,
#          'integrated': 1,
#          'advancing': 2,
#          'updating': 1,
#          'correct': 1,
#          'pcce': 1,
#          'personality': 1,
#          'communicative': 1,
#          'community': 3,
#          'broadcasting': 1,
#          'step': 1,
#          'nonlinear': 1,
#          'dimension': 4,
#          'v': 4,
#          'non': 5,
#          'simple': 2,
#          'pre': 2,
#          'bit': 1,
#          'oriented': 6,
#          'aggregation': 3,
#          'contextual': 2,
#          'federated': 1,
#          'recommender': 1,
#          'implication': 8,
#          'era': 31,
#          'decomposition': 2,
#          'va': 1,
#          'store': 3,
#          'virtual': 2,
#          'approximate': 1,
#          'supporting': 2,
#          'repetitive': 1,
#          'genome': 2,
#          'sequence': 2,
#          'semi': 1,
#          'automatic': 1,
#          'fact': 1,
#          'suspicious': 1,
#          'tax': 1,
#          'evasion': 1,
#          'group': 5,
#          'direction': 2,
#          'uncertainty': 6,
#          'measure': 1,
#          'conflict': 1,
#          'dempster': 1,
#          'shafer': 1,
#          'neighbour': 1,
#          'join': 2,
#          'theoretical': 5,
#          'feasibility': 1,
#          'bias': 2,
#          'sample': 2,
#          'sequential': 1,
#          'localization': 2,
#          'telco': 1,
#          'linked': 1,
#          'effective': 2,
#          'clinical': 10,
#          'chunk': 1,
#          'source': 1,
#          'recursive': 1,
#          'approximation': 5,
#          'recovery': 2,
#          'dataset': 1,
#          'sensory': 1,
#          'skia': 1,
#          'textual': 1,
#          'canonical': 1,
#          'correlation': 2,
#          'multiview': 1,
#          'fractional': 1,
#          'hot': 3,
#          'deck': 1,
#          'imputation': 2,
#          'variance': 1,
#          'incomplete': 1,
#          'curing': 1,
#          'emulated': 1,
#          'identification': 5,
#          'series': 5,
#          'factorization': 2,
#          'blind': 1,
#          'factor': 4,
#          'vecchia': 1,
#          'laplace': 1,
#          'gaussian': 2,
#          'distrubted': 1,
#          'dws': 1,
#          'technique': 12,
#          'access': 6,
#          'competitive': 6,
#          'advantage': 4,
#          'car': 5,
#          'hailing': 1,
#          'eu': 1,
#          'law': 4,
#          'face': 2,
#          'shake': 1,
#          'course': 3,
#          'given': 1,
#          'student': 4,
#          'expectation': 1,
#          'frame': 1,
#          'make': 4,
#          'friendly': 1,
#          'transformation': 8,
#          'enriched': 1,
#          'simplified': 2,
#          'commentary': 1,
#          'mo': 2,
#          'orthopaedic': 1,
#          'generalizability': 1,
#          'exchange': 1,
#          'material': 4,
#          'format': 1,
#          'oracle': 2,
#          'sparc': 2,
#          'accelerates': 1,
#          'integrate': 1,
#          'hardware': 1,
#          'acceleration': 1,
#          'software': 5,
#          'also': 2,
#          'enable': 1,
#          'working': 2,
#          'field': 6,
#          'augmented': 1,
#          'ethnography': 1,
#          'candidate': 3,
#          'interaction': 1,
#          'election': 1,
#          'ready': 2,
#          'hazy': 1,
#          'easier': 1,
#          'maintain': 1,
#          'racing': 1,
#          'unleash': 1,
#          'full': 1,
#          'latest': 2,
#          'railway': 1,
#          'track': 2,
#          'maintenance': 1,
#          'efficiency': 6,
#          'artificial': 5,
#          'neural': 2,
#          'energy': 18,
#          'lesson': 4,
#          'assembling': 1,
#          'critical': 6,
#          'realm': 1,
#          'possibility': 2,
#          'emergence': 2,
#          'capital': 2,
#          'formation': 1,
#          'entropy': 1,
#          'alloy': 1,
#          'growth': 4,
#          'exception': 1,
#          'parallelized': 1,
#          'technologien': 1,
#          'der': 5,
#          'fahrzeugentwicklung': 1,
#          'safety': 8,
#          'conceptual': 4,
#          'influencing': 2,
#          'question': 8,
#          'horizontal': 1,
#          'vertical': 1,
#          'discussion': 4,
#          'disaster': 6,
#          'protein': 2,
#          'structure': 2,
#          'metagenomics': 1,
#          'give': 1,
#          'boost': 3,
#          'gesch': 1,
#          'ftsmodelle': 1,
#          'die': 1,
#          'drei': 1,
#          'seiten': 1,
#          'medaille': 1,
#          'informatics': 4,
#          'smarter': 1,
#          'prevention': 3,
#          'sphps': 1,
#          'screening': 3,
#          'bregman': 1,
#          'divergence': 1,
#          'spectrum': 2,
#          'g': 1,
#          'reflection': 1,
#          'electron': 1,
#          'diffraction': 1,
#          'epitaxial': 1,
#          'film': 2,
#          'anwendungsf': 1,
#          'lle': 1,
#          'methodisch': 1,
#          'erarbeiten': 1,
#          'mechanism': 2,
#          'policy': 9,
#          'edge': 3,
#          'biomarkers': 1,
#          'dynamical': 1,
#          'drug': 8,
#          'sensitivity': 2,
#          'individual': 2,
#          'charge': 1,
#          'consumption': 3,
#          'electric': 6,
#          'vehicle': 6,
#          'government': 6,
#          'satellite': 2,
#          'yearly': 1,
#          'generation': 8,
#          'aiaa': 1,
#          'cluster': 5,
#          'highlight': 1,
#          'incorporating': 1,
#          'smallholder': 2,
#          'palm': 1,
#          'oil': 4,
#          'production': 6,
#          'battery': 1,
#          'recycling': 1,
#          'streaming': 1,
#          'concept': 3,
#          'drift': 1,
#          'literature': 5,
#          'multiperspective': 1,
#          'stem': 2,
#          'tissue': 1,
#          'vision': 1,
#          'unique': 1,
#          'bioinformatics': 2,
#          'workflow': 3,
#          'comparative': 3,
#          'three': 2,
#          'aerial': 2,
#          'laser': 1,
#          'scanning': 2,
#          'x': 3,
#          'ray': 1,
#          'contrast': 1,
#          'imaging': 3,
#          'stack': 1,
#          'seismic': 1,
#          'inversion': 1,
#          'curation': 1,
#          'coming': 1,
#          'promise': 7,
#          'mitigation': 1,
#          'next': 7,
#          'transfer': 2,
#          'maximizing': 1,
#          'throughput': 2,
#          'type': 2,
#          'gene': 4,
#          'expression': 2,
#          'carbon': 3,
#          'emission': 1,
#          'walkable': 1,
#          'quantification': 1,
#          'variation': 1,
#          'revamp': 1,
#          'toxicology': 1,
#          'parking': 1,
#          'adherence': 1,
#          'meter': 2,
#          'limit': 1,
#          'washington': 1,
#          'blockwise': 1,
#          'gradient': 1,
#          ...})

# %%
# 출현 횟수가 많은 상위 50개 단어 중에서 단어 길이가 1보다 큰 것만 딕셔너리에 저장한 후 출력

word_count = dict()
for tag, counts in count.most_common(50):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print("%s : %d" % (tag, counts))
# Out:
# data : 1238
# big : 1111
# analytics : 110
# based : 103
# analysis : 92
# driven : 71
# system : 62
# approach : 59
# using : 56
# issue : 48
# learning : 48
# model : 45
# challenge : 44
# application : 41
# new : 41
# special : 38
# algorithm : 36
# call : 35
# science : 35
# framework : 35
# platform : 34
# management : 33
# health : 33
# paper : 32
# research : 32
# era : 31
# cloud : 30
# opportunity : 27
# technology : 27
# machine : 26
# processing : 26
# mining : 26
# network : 26
# computing : 25
# earth : 25
# performance : 25
# method : 25
# perspective : 24
# optimization : 24
# business : 23
# smart : 23
# distributed : 23
# process : 23
# information : 22
# use : 22
# intelligence : 21
# review : 21
# service : 21
# development : 20
# world : 20

# %%
sorted_Keys = sorted(word_count, key = word_count.get, reverse = True) #reverse =False이면 반대로 그려짐
sorted_Values = sorted(word_count.values(), reverse = True)
plt.bar(range(len(word_count)), sorted_Values, align = 'center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation = 'vertical') #키이름이 세로로 쓰기(가로로 쓰기엔 공간이 없다)
plt.show()

# %%
#딕셔너리에서 big,data빼고 그리기
del word_count['big']
del word_count['data']

sorted_Keys = sorted(word_count, key = word_count.get, reverse = True)
sorted_Values = sorted(word_count.values(), reverse = True)
plt.bar(range(len(word_count)), sorted_Values, align = 'center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation = 'vertical')
plt.show()

# %%
# (concat만 시킨 데이터 프레임에)

# all_files_data_concat에 doc_count 컬럼을 추가한 뒤 0으로 초기화
all_files_data_concat['doc_count'] = 0 #하는 이유?

summary_year = all_files_data_concat.groupby('출판일', as_index = False)['doc_count'].count() 
summary_year #출력하여 내용 확인
# Out:
#      출판일  doc_count
# 0   1995          1
# 1   2003          1
# 2   2004          1
# 3   2011          5
# 4   2012         20
# 5   2013         49
# 6   2014        123
# 7   2015         92
# 8   2016        119
# 9   2017        126
# 10  2018        117
# 11  2019         91
# 12  2020        102
# 13  2021         92
# 14  2022         57
# 15  2023          4

# %%
plt.figure(figsize = (12, 5))
plt.xlabel("year")
plt.ylabel("doc-count")
plt.grid(True)
plt.plot(range(len(summary_year)), summary_year['doc_count'])
plt.xticks(range(len(summary_year)), [text for text in summary_year['출판일']])
plt.show()

# %%
stopwords = set(STOPWORDS)
wc = WordCloud(background_color = 'ivory', stopwords = stopwords, width = 800, height = 600)

#generate_from_frequencies메소드, word_count: 상위50개 추출한 딕셔너리
cloud = wc.generate_from_frequencies(word_count)

plt.figure(figsize = (8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
cloud.to_file("8장_data/riss_bigdata_wordCloud.jpg")
